# %%
import warnings

warnings.filterwarnings('ignore', category=Warning)

# %%
import os
import sys

sys.path.append(os.path.abspath(os.path.join(os.getcwd(), "../..")))

# %%
from traj_xai.src import SimpleTransformerModel, TrajFormerModel

# %%
from pactus import Dataset

# %% [markdown]
# ## Segmentation

# %%
from traj_xai.src import (
    mdl_segmentation,
    rdp_segmentation,
    sliding_window_segmentation,
)

# %% [markdown]
# ## Pertubation

# %%
from traj_xai.src import (
    gaussian_perturbation,
    scaling_perturbation,
    rotation_perturbation,
)

# %% [markdown]
# ## Evaluation

# %% [markdown]
# ## Experiment with all trajectories

# %%
# LSTM Model
SEED = 0

# datasets = [
#     # Dataset.geolife(),
#     Dataset.animals(),
#     Dataset.hurdat2(),
#     Dataset.uci_characters(),
#     Dataset.uci_pen_digits(),
#     Dataset.uci_movement_libras(),
#     Dataset.mnist_stroke()
# ]

# Load dataset
dataset = Dataset.mnist_stroke() #uci_characters()

# # check datasets for temporal data
# for ds in datasets:
#     print(ds.dataset_name, all(x.t is not None for x in ds.trajs))

# Split data into train and test subsets
train, test = dataset.split(0.8, random_state=SEED)

# train_sets = []
# test_sets = []
# for ds in datasets:
#     train, test = ds.split(0.8, random_state=SEED)
#     train_sets.append(train)
#     test_sets.append(test)

# %% [markdown]
# ### DL Model

# %%
max_length = 1000
embedding_size = 64

# Build and train the model
model = TrajFormerModel(
    c_out=len(dataset.classes),
)

# Train the model on the train dataset
model.train(train, dataset, epochs=10, batch_size=16)#64)

# Evaluate the model on a test dataset
evaluation = model.evaluate(test)

# Print the evaluation
evaluation.show()
# Out:
# 16:43:32 [INFO] Epoch 10/10, Loss: 289.7247
# 16:43:32 [INFO] Trained TrajFormer model with 56000 samples
# ---------------------------------------------------------------------------
# OutOfMemoryError                          Traceback (most recent call last)
# Cell In[8], line 13
#      10 model.train(train, dataset, epochs=10, batch_size=16)#64)
#      12 # Evaluate the model on a test dataset
# ---> 13 evaluation = model.evaluate(test)
#      15 # Print the evaluation
#      16 evaluation.show()
#
# File c:\Users\nickz\Downloads\# SJSU Classes\CMPE 252\XAI4Traj\traj_xai\src\models\trajformer\trajformer_model.py:158, in TrajFormerModel.evaluate(self, data)
#     155 assert self.encoder is not None, "Encoder is not set."
#     157 # Get predicted probabilities
# --> 158 probabilities = self.predict(data)
#     160 # Get class with highest probability for each sample
#     161 pred_indices = np.argmax(probabilities, axis=1)
#
# File c:\Users\nickz\Downloads\# SJSU Classes\CMPE 252\XAI4Traj\traj_xai\src\models\trajformer\trajformer_model.py:148, in TrajFormerModel.predict(self, data)
#     146 self.model.eval()
#     147 with torch.no_grad():
# --> 148     outputs = self.model(x_trajs, masks, distances)
#     149     probabilities = F.softmax(outputs, dim=1).cpu().numpy()
#     151 return probabilities
#
# File c:\Users\nickz\miniconda3\envs\traj_xai\lib\site-packages\torch\nn\modules\module.py:1736, in Module._wrapped_call_impl(self, *args, **kwargs)
#    1734     return self._compiled_call_impl(*args, **kwargs)  # type: ignore[misc]
#    1735 else:
# -> 1736     return self._call_impl(*args, **kwargs)
#
# File c:\Users\nickz\miniconda3\envs\traj_xai\lib\site-packages\torch\nn\modules\module.py:1747, in Module._call_impl(self, *args, **kwargs)
#    1742 # If we don't have any hooks, we want to skip the rest of the logic in
#    1743 # this function, and just call forward.
#    1744 if not (self._backward_hooks or self._backward_pre_hooks or self._forward_hooks or self._forward_pre_hooks
#    1745         or _global_backward_pre_hooks or _global_backward_hooks
#    1746         or _global_forward_hooks or _global_forward_pre_hooks):
# -> 1747     return forward_call(*args, **kwargs)
#    1749 result = None
#    1750 called_always_called_hooks = set()
#
# File c:\Users\nickz\Downloads\# SJSU Classes\CMPE 252\XAI4Traj\traj_xai\src\models\trajformer\trajformer_model.py:32, in TrajFormerWrapper.forward(self, x_trajs, masks, distances)
#      29 distances = distances.to(self.device)
#      31 # Forward pass through the base model
# ---> 32 return self.model(x_trajs, masks, distances)
#
# File c:\Users\nickz\miniconda3\envs\traj_xai\lib\site-packages\torch\nn\modules\module.py:1736, in Module._wrapped_call_impl(self, *args, **kwargs)
#    1734     return self._compiled_call_impl(*args, **kwargs)  # type: ignore[misc]
#    1735 else:
# -> 1736     return self._call_impl(*args, **kwargs)
#
# File c:\Users\nickz\miniconda3\envs\traj_xai\lib\site-packages\torch\nn\modules\module.py:1747, in Module._call_impl(self, *args, **kwargs)
#    1742 # If we don't have any hooks, we want to skip the rest of the logic in
#    1743 # this function, and just call forward.
#    1744 if not (self._backward_hooks or self._backward_pre_hooks or self._forward_hooks or self._forward_pre_hooks
#    1745         or _global_backward_pre_hooks or _global_backward_hooks
#    1746         or _global_forward_hooks or _global_forward_pre_hooks):
# -> 1747     return forward_call(*args, **kwargs)
#    1749 result = None
#    1750 called_always_called_hooks = set()
#
# File c:\Users\nickz\Downloads\# SJSU Classes\CMPE 252\XAI4Traj\traj_xai\src\models\trajformer\trajformer.py:405, in TrajFormer.forward(self, x, m, dis, pad)
#     402     inputs = x
#     403     _len = [len(i) for i in x]
# --> 405 out = self.forward_features(x, m, dis, pad)  # [b, n+1, c]
#     407 if self.depth > 0:
#     408     out = out[:, 0]
#
# File c:\Users\nickz\Downloads\# SJSU Classes\CMPE 252\XAI4Traj\traj_xai\src\models\trajformer\trajformer.py:384, in TrajFormer.forward_features(self, x, m, dis, pad)
#     382     out = self.conv1d(inputs.permute(0, 2, 1))  # b, token_dim, n_time
#     383     # b, n_time, token_dim
# --> 384     out = self.involution(out.unsqueeze(-1), dis).squeeze().permute(0, 2, 1)
#     385 else:
#     386     out = self.conv1d(inputs.permute(0, 2, 1)).permute(
#     387         0, 2, 1
#     388     )  # b, n_time, token_dim
#
# File c:\Users\nickz\miniconda3\envs\traj_xai\lib\site-packages\torch\nn\modules\module.py:1736, in Module._wrapped_call_impl(self, *args, **kwargs)
#    1734     return self._compiled_call_impl(*args, **kwargs)  # type: ignore[misc]
#    1735 else:
# -> 1736     return self._call_impl(*args, **kwargs)
#
# File c:\Users\nickz\miniconda3\envs\traj_xai\lib\site-packages\torch\nn\modules\module.py:1747, in Module._call_impl(self, *args, **kwargs)
#    1742 # If we don't have any hooks, we want to skip the rest of the logic in
#    1743 # this function, and just call forward.
#    1744 if not (self._backward_hooks or self._backward_pre_hooks or self._forward_hooks or self._forward_pre_hooks
#    1745         or _global_backward_pre_hooks or _global_backward_hooks
#    1746         or _global_forward_hooks or _global_forward_pre_hooks):
# -> 1747     return forward_call(*args, **kwargs)
#    1749 result = None
#    1750 called_always_called_hooks = set()
#
# File c:\Users\nickz\Downloads\# SJSU Classes\CMPE 252\XAI4Traj\traj_xai\src\models\trajformer\trajformer.py:200, in CPE_Block.forward(self, x, dis)
#     198 residual = x
#     199 for block in self.blocks:
# --> 200     x = block(x, dis)
#     201 return x + residual
#
# File c:\Users\nickz\miniconda3\envs\traj_xai\lib\site-packages\torch\nn\modules\module.py:1736, in Module._wrapped_call_impl(self, *args, **kwargs)
#    1734     return self._compiled_call_impl(*args, **kwargs)  # type: ignore[misc]
#    1735 else:
# -> 1736     return self._call_impl(*args, **kwargs)
#
# File c:\Users\nickz\miniconda3\envs\traj_xai\lib\site-packages\torch\nn\modules\module.py:1747, in Module._call_impl(self, *args, **kwargs)
#    1742 # If we don't have any hooks, we want to skip the rest of the logic in
#    1743 # this function, and just call forward.
#    1744 if not (self._backward_hooks or self._backward_pre_hooks or self._forward_hooks or self._forward_pre_hooks
#    1745         or _global_backward_pre_hooks or _global_backward_hooks
#    1746         or _global_forward_hooks or _global_forward_pre_hooks):
# -> 1747     return forward_call(*args, **kwargs)
#    1749 result = None
#    1750 called_always_called_hooks = set()
#
# File c:\Users\nickz\Downloads\# SJSU Classes\CMPE 252\XAI4Traj\traj_xai\src\models\trajformer\trajformer.py:255, in CPE.forward(self, x, dis)
#     247 k = F.unfold(
#     248     x, (self.kernel_size, 1), 1, ((self.kernel_size - 1) // 2, 0), self.stride
#     249 ).reshape(
#     250     b, c, self.kernel_size, -1
#     251 )  # b, c, k, n
#     253 k = k.permute(0, 3, 2, 1).reshape(-1, self.kernel_size, c)  # bn, k, c
#     254 kv = (
# --> 255     self.kv_func(k)
#     256     .reshape(
#     257         b * t * w, self.kernel_size, 2, self.num_heads, c // self.num_heads
#     258     )
#     259     .permute(2, 0, 3, 1, 4)
#     260 )
#     261 k, v = kv[0], kv[1]  # bn, groups, k, c'
#     262 # P.S. we find using key doesn't improve performance thus ignore it in the following computations
#
# File c:\Users\nickz\miniconda3\envs\traj_xai\lib\site-packages\torch\nn\modules\module.py:1736, in Module._wrapped_call_impl(self, *args, **kwargs)
#    1734     return self._compiled_call_impl(*args, **kwargs)  # type: ignore[misc]
#    1735 else:
# -> 1736     return self._call_impl(*args, **kwargs)
#
# File c:\Users\nickz\miniconda3\envs\traj_xai\lib\site-packages\torch\nn\modules\module.py:1747, in Module._call_impl(self, *args, **kwargs)
#    1742 # If we don't have any hooks, we want to skip the rest of the logic in
#    1743 # this function, and just call forward.
#    1744 if not (self._backward_hooks or self._backward_pre_hooks or self._forward_hooks or self._forward_pre_hooks
#    1745         or _global_backward_pre_hooks or _global_backward_hooks
#    1746         or _global_forward_hooks or _global_forward_pre_hooks):
# -> 1747     return forward_call(*args, **kwargs)
#    1749 result = None
#    1750 called_always_called_hooks = set()
#
# File c:\Users\nickz\miniconda3\envs\traj_xai\lib\site-packages\torch\nn\modules\linear.py:125, in Linear.forward(self, input)
#     124 def forward(self, input: Tensor) -> Tensor:
# --> 125     return F.linear(input, self.weight, self.bias)
#
# OutOfMemoryError: CUDA out of memory. Tried to allocate 6.01 GiB. GPU 0 has a total capacity of 4.00 GiB of which 0 bytes is free. Of the allocated memory 3.67 GiB is allocated by PyTorch, and 5.86 GiB is reserved by PyTorch but unallocated. If reserved but unallocated memory is large try setting PYTORCH_CUDA_ALLOC_CONF=expandable_segments:True to avoid fragmentation.  See documentation for Memory Management  (https://pytorch.org/docs/stable/notes/cuda.html#environment-variables)

# %% [markdown]
# ### ML Model

# %%
# # ML Model
# SEED = 0

# # datasets = [
# #     # Dataset.geolife(),
# #     Dataset.animals(),
# #     # Dataset.hurdat2(), -> RF cant work
# #     Dataset.cma_bst(),
# #     # Dataset.mnist_stroke(), -> okay
# #     # Dataset.uci_pen_digits(),
# #     # Dataset.uci_gotrack(),
# #     Dataset.uci_characters(),
# #     Dataset.uci_movement_libras(),-> okay
# # ]

# # Load dataset
# dataset = Dataset.geolife()

# # Split data into train and test subsets
# # train, test = dataset.split(.995, random_state=SEED)

# train, test = dataset.filter(
#         lambda traj, label: len(traj) >= 5
#         and traj.r.delta.norm.sum() > 0
#         and dataset.label_counts[label] > 5
#     ).split(
#         train_size=0.985,
#         random_state=SEED,
#     )

# # Build and train the model
# featurizer = featurizers.UniversalFeaturizer()
# model = XGBoostModel(featurizer=featurizer)
# model = SVMModel(
#     featurizer=featurizer,
#     random_state=SEED,
# )
# DecisionTreeModel(
#     featurizer=featurizer,
#     max_depth=7,
#     random_state=SEED,
# )


# # Train the model on the train dataset
# model.train(train, 5) # 5: CV

# # Evaluate the model on a test dataset
# evaluation = model.evaluate(test)

# # Print the evaluation
# evaluation.show()

# %% [markdown]
# ### Experiment

# %%
from traj_xai.src import run_experiments

# %%
train.trajs[1].r
# Out:
# Vector([[12.,  9.],
#         [12., 10.],
#         [12., 11.],
#         [11., 11.],
#         [11., 12.],
#         [11., 13.],
#         [11., 14.],
#         [10., 15.],
#         [10., 16.],
#         [10., 17.],
#         [10., 18.],
#         [10., 19.],
#         [10., 20.],
#         [11., 21.],
#         [11., 22.],
#         [12., 22.],
#         [13., 22.],
#         [14., 22.],
#         [15., 22.],
#         [16., 22.],
#         [17., 22.],
#         [18., 22.],
#         [18., 21.],
#         [19., 21.],
#         [19., 20.],
#         [20., 19.],
#         [20., 18.],
#         [20., 17.],
#         [20., 16.],
#         [20., 15.],
#         [21., 14.],
#         [21., 13.],
#         [21., 12.],
#         [20., 11.],
#         [20., 10.],
#         [20.,  9.],
#         [20.,  8.],
#         [20.,  7.],
#         [19.,  7.],
#         [19.,  6.],
#         [19.,  5.],
#         [18.,  5.],
#         [17.,  4.],
#         [16.,  5.],
#         [15.,  6.],
#         [15.,  7.],
#         [14.,  7.],
#         [13.,  8.]])

# %%
segment_func = [sliding_window_segmentation]
perturbation_func = [rotation_perturbation]

run_experiments(test, segment_func, perturbation_func, model)
# Out:
# 16:47:01 [INFO] Running experiment with sliding_window_segmentation and rotation_perturbation
# 16:47:01 [DEBUG] Starting explanation process...
# 16:47:01 [DEBUG] Normalizing predictions: type=<class 'numpy.ndarray'>, shape=(256, 10)
# 16:47:02 [INFO] Finished explanation process.
# 16:47:02 [DEBUG] Starting get_Y process...
# 16:47:02 [ERROR] Error in _predict: not enough values to unpack (expected 3, got 2)
# Traceback (most recent call last):
#   File "c:\Users\nickz\Downloads\# SJSU Classes\CMPE 252\XAI4Traj\traj_xai\src\xai.py", line 155, in _predict
#     result = self.model.predict(X)
#   File "c:\Users\nickz\Downloads\# SJSU Classes\CMPE 252\XAI4Traj\traj_xai\src\models\trajformer\trajformer_model.py", line 148, in predict
#     outputs = self.model(x_trajs, masks, distances)
#   File "c:\Users\nickz\miniconda3\envs\traj_xai\lib\site-packages\torch\nn\modules\module.py", line 1736, in _wrapped_call_impl
#     return self._call_impl(*args, **kwargs)
#   File "c:\Users\nickz\miniconda3\envs\traj_xai\lib\site-packages\torch\nn\modules\module.py", line 1747, in _call_impl
#     return forward_call(*args, **kwargs)
#   File "c:\Users\nickz\Downloads\# SJSU Classes\CMPE 252\XAI4Traj\traj_xai\src\models\trajformer\trajformer_model.py", line 32, in forward
#     return self.model(x_trajs, masks, distances)
#   File "c:\Users\nickz\miniconda3\envs\traj_xai\lib\site-packages\torch\nn\modules\module.py", line 1736, in _wrapped_call_impl
#     return self._call_impl(*args, **kwargs)
#   File "c:\Users\nickz\miniconda3\envs\traj_xai\lib\site-packages\torch\nn\modules\module.py", line 1747, in _call_impl
#     return forward_call(*args, **kwargs)
#   File "c:\Users\nickz\Downloads\# SJSU Classes\CMPE 252\XAI4Traj\traj_xai\src\models\trajformer\trajformer.py", line 405, in forward
#     out = self.forward_features(x, m, dis, pad)  # [b, n+1, c]
#   File "c:\Users\nickz\Downloads\# SJSU Classes\CMPE 252\XAI4Traj\traj_xai\src\models\trajformer\trajformer.py", line 372, in forward_features
#     b, n_time, in_channels = inputs.shape
# ValueError: not enough values to unpack (expected 3, got 2)
# 16:47:02 [ERROR] Error in get_Y: not enough values to unpack (expected 3, got 2)
# Traceback (most recent call last):
#   File "c:\Users\nickz\Downloads\# SJSU Classes\CMPE 252\XAI4Traj\traj_xai\src\xai.py", line 377, in get_Y
#     preds = self._predict(Z_pro)
#   File "c:\Users\nickz\Downloads\# SJSU Classes\CMPE 252\XAI4Traj\traj_xai\src\xai.py", line 155, in _predict
#     result = self.model.predict(X)
#   File "c:\Users\nickz\Downloads\# SJSU Classes\CMPE 252\XAI4Traj\traj_xai\src\models\trajformer\trajformer_model.py", line 148, in predict
#     outputs = self.model(x_trajs, masks, distances)
#   File "c:\Users\nickz\miniconda3\envs\traj_xai\lib\site-packages\torch\nn\modules\module.py", line 1736, in _wrapped_call_impl
#     return self._call_impl(*args, **kwargs)
#   File "c:\Users\nickz\miniconda3\envs\traj_xai\lib\site-packages\torch\nn\modules\module.py", line 1747, in _call_impl
#     return forward_call(*args, **kwargs)
#   File "c:\Users\nickz\Downloads\# SJSU Classes\CMPE 252\XAI4Traj\traj_xai\src\models\trajformer\trajformer_model.py", line 32, in forward
#     return self.model(x_trajs, masks, distances)
#   File "c:\Users\nickz\miniconda3\envs\traj_xai\lib\site-packages\torch\nn\modules\module.py", line 1736, in _wrapped_call_impl
#     return self._call_impl(*args, **kwargs)
#   File "c:\Users\nickz\miniconda3\envs\traj_xai\lib\site-packages\torch\nn\modules\module.py", line 1747, in _call_impl
#     return forward_call(*args, **kwargs)
#   File "c:\Users\nickz\Downloads\# SJSU Classes\CMPE 252\XAI4Traj\traj_xai\src\models\trajformer\trajformer.py", line 405, in forward
#     out = self.forward_features(x, m, dis, pad)  # [b, n+1, c]
#   File "c:\Users\nickz\Downloads\# SJSU Classes\CMPE 252\XAI4Traj\traj_xai\src\models\trajformer\trajformer.py", line 372, in forward_features
#     b, n_time, in_channels = inputs.shape
# ValueError: not enough values to unpack (expected 3, got 2)
# 16:47:02 [ERROR] Trajectory 0: prediction failed
# 16:47:02 [WARNING] RAM usage too high. Pausing experiment...
# 16:47:02 [INFO] Results saved to logs\sliding_window_segmentation_rotation_perturbation_results.csv
# [INFO] Row saved to logs\sliding_window_segmentation_rotation_perturbation_results.csv: [0, 'traj_183b613f', None, None, 'error_predict']
# 2025-10-21 16:47:02 - Total RAM: 13.86 GB | Used: 92.8%
